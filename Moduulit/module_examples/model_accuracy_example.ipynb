# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import sys
sys.path.append("/home/jovyan/work/TeamAdconsys/Tuomas/modules/")
from rounding import rounding
from dataloaders import dataloaders

from sklearn import preprocessing
import torch.nn as nn
import torch.nn.functional as F
from torch import nn, optim

# %%
train_loader, test_loader, val_loader, large_test_loader = dataloaders('/home/jovyan/work/TeamAdconsys/Tuomas/NN_data/new_data')
# Out:
# -------------------------------------------------------------
# ------------------ Creating Dataloaders ---------------------
# -------------------------------------------------------------
#
# Reading csv-files from /home/jovyan/work/TeamAdconsys/Tuomas/NN_data/new_data/
#
# Dataloaders:
# train_loader: 6405
# test_loader: 951
# val_loader: 797
# large_test_loader: 8153
#
#
# Done in 2.14 seconds.

# %%
from model_accuracy import accuracy
accuracy('multimargin.pth', test_loader)
# Out:
# -------------------------------------------------------------
# ----------------------- Model Accuracy ----------------------
# -------------------------------------------------------------
#
# Model: multimargin.pth
# Accuracy: 0.8003451392883557
#
#
# Done in 16.84 seconds.
